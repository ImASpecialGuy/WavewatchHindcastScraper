# %%
from bs4 import BeautifulSoup
import requests

# %%
URL = "https://polar.ncep.noaa.gov/waves/hindcasts/nopp-phase2/"
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.text)
soup
# Out:
# <!DOCTYPE html>
#
# <head>
# <title>Files in /waves/hindcasts/nopp-phase2</title>
# <style>
#   td.right {text-align:right}
#   td,th {padding:1px 15px 0px 15px}
#   th {text-decoration:bold}
# </style>
# </head>
# <body>
# <h2>Files in /waves/hindcasts/nopp-phase2</h2>
# <table><tr><th>Name</th><th>Last changed</th><th>Size</th></tr>
# <tr><th colspan="3"><hr/></th></tr>
# <tr><td colspan="3"><img alt="[DIR]" src="/ncep_common/back.gif"/>  <a href="../">Parent Directory</a></td></tr>
# <tr><td><img alt="directory" src="/ncep_common/dir.gif"/>  <a href="197901">197901</a></td><td>08-Nov-2019 17:32</td><td class="right">4K</td></tr>
# <tr><td><img alt="directory" src="/ncep_common/dir.gif"/>  <a href="197902">197902</a></td><td>08-Nov-2019 17:39</td><td class="right">4K</td></tr>
# <tr><td><img alt="directory" src="/ncep_common/dir.gif"/>  <a href="197903">197903</a></td><td>08-Nov-2019 17:39</td><td class="right">4K</td></tr>
# ...

# %% [markdown]
# Purpose:
# *download data (use dummy files for testing)
#
# Questions:
# *Q: How does it download it?
#  A: Mimic original file structure
# *Q: What options for downloading?
#  A: *date range (start date and end date)
#     *features (Hs, wave period tp, wave direction dp, wind uv)
#     *regions (global, arctic ocean, alaskan, etc.)
#     *include daily bulk spectral estimates per system
#     *include point output
#
# Method:
# *Start with parsing options
# *For loop through dates
#   *For loop for each region
#     *For loop for each option (create folders and download files)
#
#
# ***FIX MEDITERRANEAN LONGITUDES***
